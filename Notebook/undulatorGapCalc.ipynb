# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def calcGap(targetE = 12, harmonics = 5):
    
    "calculate the gap for a given E and harmonics using the polynomial fit"
    
    E1 = targetE/harmonics
     
    gap = 0.655+(4.380*E1)-(1.085*E1**2)+(0.202*E1**3) #equation from curve fit
    
    return np.around(gap*1000,1) #one decimal 




def FindGap(targetE =12):
    
    "Estimate a suitable gap for target energy"
    
    harmonics = [3,5,7,9] #harmonics options
    
    if targetE>5.5 and targetE<25:     # if dialed a wrong number
    
        opt = np.array([calcGap(targetE = targetE, harmonics = hm) for hm in harmonics])
    
        return opt[np.where(np.logical_and(opt>=6000, opt<=10000))][-1] #last one has lowest gap in the list
    
    else:
        print(" Requested Energy is out of range")
        return

        
def moveEnergy(E = 12):
    
    ugap_ = findGap(targetE = E)
    yield from bps.mov(e, E)
    yield from bps.mov(ugap, ugap_)
    
    print(f"Current energy is {e.position} ")
    

    
def optimizePitch():
    
    #find curvefit eqn for HFM and Pitch
    #go to appr. pitch
    #find beam at ssa2(open),  follow ic1
    #close ssa horz. and center HFM coarse
    #scan the pitch 
    
    pass

# %%
df = pd.DataFrame(columns= ['Energy', 'calcGap'], dtype=object,index=range(50))

for i in range(0,30):
    df.loc[i].Energy = i
    df.loc[i].calcGap = suggestAGap(targetE = i)
# Out:
#  Requested Energy is out of range
#  Requested Energy is out of range
#  Requested Energy is out of range
#  Requested Energy is out of range
#  Requested Energy is out of range
#  Requested Energy is out of range
#  Requested Energy is out of range
#  Requested Energy is out of range
#  Requested Energy is out of range
#  Requested Energy is out of range
#  Requested Energy is out of range

# %%
df = pd.
# Out:
#    Energy calcGap
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
# 5     NaN     NaN
# 6       0    None
# 7       1    None
# 8       2    None
# 9       3    None
# 10      4    None
# 11      5    None
# 12      6    6691
# 13      7  7533.9
# 14      8    8450
# 15      9  6201.7
# 16     10    6691
# 17     11  7190.5
# 18     12  7709.8
# 19     13    6341
# 20     14    6691
# 21     15  7046.2
# 22     16  6147.5
# 23     17  6418.5
# 24     18    6691
# 25     19  6966.6
# 26     20    7247
# 27     21  7533.9
# 28     22  7828.9
# 29     23  8133.7
# 30     24    8450
# 31     25    None
# 32     26    None
# 33     27    None
# 34     28    None
# 35     29    None
# 36    NaN     NaN
# 37    NaN     NaN
# 38    NaN     NaN
# 39    NaN     NaN
# 40    NaN     NaN
# 41    NaN     NaN
# 42    NaN     NaN
# 43    NaN     NaN
# 44    NaN     NaN
# 45    NaN     NaN
# 46    NaN     NaN
# 47    NaN     NaN
# 48    NaN     NaN
# 49    NaN     NaN

# %%
df = pd.read_csv("ugap_calib.csv")

# %%
df["dcm-pitch"][df["energy"] == 12]
# Out:
# 24    0.96023
# Name: dcm-pitch, dtype: float64

# %%
en = df["energy"].to_numpy()
dcm_p = df["dcm-pitch"].to_numpy()

# %%
plt.plot(en,dcm_p)

coeff = np.polyfit(en,dcm_p,3)

plt.plot(en, np.polyval(coeff, en))

# %%
df.head(20)
# Out:
#     Unnamed: 0                          Time Stamp  energy  harmonic  \
# 0            0  2022+AC0-05+AC0-26 17:42:51.253183    6.00         3
